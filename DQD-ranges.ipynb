# %% [markdown]
# # eMERGE Numeric Lab - Plausible Ranges
#
# For the selected numeric labs at [https://docs.google.com/spreadsheets/d/1pi0N850Bdicz3zCyR4VS70a4UR5ckHUCvp4T91V_V3o/edit#gid=416924767](https://docs.google.com/spreadsheets/d/1pi0N850Bdicz3zCyR4VS70a4UR5ckHUCvp4T91V_V3o/edit#gid=416924767), get the plausible lab value ranges as defined by the OHDSI [DataQualityDashboard](https://github.com/OHDSI/DataQualityDashboard).
#
# Condition leads should review the provided ranges to ensure they are accurate for their respective condition.

# %%
import pandas as pd

# Data is sourced from https://raw.githubusercontent.com/OHDSI/DataQualityDashboard/master/inst/csv/OMOP_CDMv5.3.1_Concept_Level.csv
# Downloaded 2022-02-24
df = pd.read_csv('OMOP_CDMv5.3.1_Concept_Level.csv')

# %% [markdown]
# ## HDL

# %%
df[(df['conceptName'].str.contains("Cholesterol in HDL [", regex=False))][['conceptName', 'unitConceptName', 'plausibleValueLow', 'plausibleValueHigh']]
# Out:
#                                            conceptName  \
# 361  Cholesterol.total/Cholesterol in HDL [Percentile]
# 382  Cholesterol in LDL/Cholesterol in HDL [Mass Ra...
# 474  Cholesterol in HDL [Mass/volume] in Serum or P...
# 475  Cholesterol in HDL [Mass/volume] in Serum or P...
# 476  Cholesterol in HDL [Mass/volume] in Serum or P...
# 477  Cholesterol in HDL [Mass/volume] in Serum or P...
# 557  Cholesterol.total/Cholesterol in HDL [Mass Rat...
# 558  Cholesterol.total/Cholesterol in HDL [Mass Rat...
#
#              unitConceptName  plausibleValueLow  plausibleValueHigh
# 361                  percent               2.00                75.0
# 382                    ratio               1.00                28.0
# 474       gram per deciliter               0.01                 5.0
# 475      micromole per liter              24.00                43.0
# 476  milligram per deciliter               5.00               150.0
# 477      millimole per liter               0.10                 5.0
# 557                  percent               1.00                75.0
# 558                    ratio               2.00               158.0

# %% [markdown]
# ## Total Cholesterol

# %%
df[(df['conceptName'].str.contains("Cholesterol [", regex=False))][['conceptName', 'unitConceptName', 'plausibleValueLow', 'plausibleValueHigh']]
# Out:
#                                        conceptName          unitConceptName  \
# 734        Cholesterol [Mass/volume] in Body fluid  milligram per deciliter
# 735  Cholesterol [Moles/volume] in Serum or Plasma  milligram per deciliter
# 839  Cholesterol [Moles/volume] in Serum or Plasma      millimole per liter
# 915   Cholesterol [Mass/volume] in Serum or Plasma       gram per deciliter
# 916   Cholesterol [Mass/volume] in Serum or Plasma  milligram per deciliter
# 932   Cholesterol [Mass/volume] in Serum or Plasma      millimole per liter
#
#      plausibleValueLow  plausibleValueHigh
# 734               50.0               500.0
# 735               50.0               500.0
# 839                1.0                15.0
# 915                2.6                36.0
# 916               90.0               400.0
# 932                1.0                15.0

# %% [markdown]
# ## Triglyceride

# %%
df[(df['conceptName'].str.contains("Triglyceride [", regex=False))][['conceptName', 'unitConceptName', 'plausibleValueLow', 'plausibleValueHigh']]
# Out:
#                                        conceptName          unitConceptName  \
# 773            Triglyceride [Mass/volume] in Blood  milligram per deciliter
# 775  Triglyceride [Mass/volume] in Serum or Plasma                  percent
# 776  Triglyceride [Mass/volume] in Serum or Plasma      millimole per liter
# 777  Triglyceride [Mass/volume] in Serum or Plasma  milligram per deciliter
#
#      plausibleValueLow  plausibleValueHigh
# 773               40.0              1000.0
# 775                0.0               100.0
# 776                1.0                10.0
# 777               40.0              1000.0

# %% [markdown]
# ## A1C

# %%
df[(df['conceptName'].str.contains("Hemoglobin A1c", regex=False))][['conceptName', 'unitConceptName', 'plausibleValueLow', 'plausibleValueHigh']]
# Out:
#                                             conceptName  \
# 422            Hemoglobin A1c/Hemoglobin.total in Blood
# 423            Hemoglobin A1c/Hemoglobin.total in Blood
# 440    Hemoglobin A1c/Hemoglobin.total in Blood by HPLC
# 483   Hemoglobin A1c/Hemoglobin.total in Blood by ca...
# 981               Hemoglobin A1c [Mass/volume] in Blood
# 982               Hemoglobin A1c [Mass/volume] in Blood
# 1164                            Hemoglobin A1c in Blood
# 1165                            Hemoglobin A1c in Blood
# 1166                            Hemoglobin A1c in Blood
# 1167                            Hemoglobin A1c in Blood
# 1168                            Hemoglobin A1c in Blood
# 1169                            Hemoglobin A1c in Blood
# 1170                            Hemoglobin A1c in Blood
# 1171                            Hemoglobin A1c in Blood
#
#               unitConceptName  plausibleValueLow  plausibleValueHigh
# 422                   percent               4.00                15.0
# 423        millimole per mole               0.00              1000.0
# 440                   percent               0.01                20.0
# 483                   percent               0.00               100.0
# 981                   percent               0.00               100.0
# 982        gram per deciliter               1.00                20.0
# 1164                    liter               0.00                 5.0
# 1165                  percent               1.00                20.0
# 1166                 picogram               0.00                10.0
# 1167                milligram               0.00                15.0
# 1168       gram per deciliter               0.00                20.0
# 1169               pound (US)               0.00               200.0
# 1170  milligram per deciliter               0.00               150.0
# 1171                inch (US)               0.00                12.0

# %% [markdown]
# ## LDL

# %%
df[(df['conceptName'].str.contains("Cholesterol in LDL", regex=False))][['conceptName', 'unitConceptName', 'plausibleValueLow', 'plausibleValueHigh']]
# Out:
#                                             conceptName  \
# 359   Cholesterol in LDL [Moles/volume] in Serum or ...
# 360   Cholesterol in LDL [Moles/volume] in Serum or ...
# 382   Cholesterol in LDL/Cholesterol in HDL [Mass Ra...
# 535   Cholesterol in LDL [Mass/volume] in Serum or P...
# 536   Cholesterol in LDL [Mass/volume] in Serum or P...
# 940   Cholesterol in HDL/Cholesterol in LDL [Mass Ra...
# 941   Cholesterol in LDL [Mass/volume] in Serum or P...
# 942   Cholesterol in LDL [Mass/volume] in Serum or P...
# 943   Cholesterol in LDL [Mass/volume] in Serum or P...
# 944   Cholesterol in LDL [Mass/volume] in Serum or P...
# 945   Cholesterol in LDL [Mass/volume] in Serum or P...
# 1064  Cholesterol in LDL [Mass/volume] in Serum or P...
#
#               unitConceptName  plausibleValueLow  plausibleValueHigh
# 359       millimole per liter                0.1                11.0
# 360        nanomole per liter               19.0              2500.0
# 382                     ratio                1.0                28.0
# 535   milligram per deciliter                1.0               400.0
# 536        nanomole per liter              418.0              2500.0
# 940                     ratio                1.0               100.0
# 941   milligram per deciliter               45.0               400.0
# 942    nanogram per deciliter               51.0               372.0
# 943        nanomole per liter               35.0               596.0
# 944   milligram per deciliter               20.0               300.0
# 945       millimole per liter                0.1                11.0
# 1064       nanomole per liter              864.0              2500.0
